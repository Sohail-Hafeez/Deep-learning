# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("/content/interview.csv")

# %%
df.head()
# Out:
#    CGPA  Resume_Score  Interview_Call
# 0  2.75          41.9               0
# 1  3.90          78.2               1
# 2  3.46          58.9               0
# 3  3.20          70.5               1
# 4  2.31          94.5               1

# %%
sns.scatterplot(x=df["CGPA"], y=df["Resume_Score"], hue=df["Interview_Call"])
# Out:
# <Axes: xlabel='CGPA', ylabel='Resume_Score'>

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-215.73,   18.3 ]])

# %%
p.intercept_
# Out:
# array([-81.])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.values , y.values , clf=p , legend =2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
